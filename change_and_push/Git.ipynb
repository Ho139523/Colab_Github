# %% [markdown]
# ### Git configurations

# %%
from google.colab import userdata
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git config --global user.name "Ho139523"
# !git config --global user.email "answereeee4@gmail.com"

# %% [markdown]
# ### Importing token and passwords

# %%
token=userdata.get('token')
username='Ho139523'
repo='Colab_Github'
proj_folder='change_and_push'

# %%
# !mkdir change_and_push
# %cd change_and_push
# !mkdir Data

# %%
# %cd ../
# !git init
# !git remote add origin https://github.com/{username}/{repo}
# !git config core.sparsecheckout true
# !git sparse-checkout set {proj_folder}
# !git pull origin HEAD:main

# %%
# %cd /content/{proj_folder}
# !cp /content/drive/MyDrive/Colab_Notebooks/Git.ipynb /content/change_and_push

# %% [markdown]
# ### Adding files and folders to ignore files

# %%
# %cd ../
# !touch .gitignore
# !echo "sample_data/" >> .gitignore
# !echo ".config/" >> .gitignore
# !echo ".git/" >> .gitignore
# !echo "drive/" >> .gitignore
# !echo ".ipynb_checkpoints/" >> .gitignore

# %%
#Commit=str(input("Please leave your message here: "))
# !git add --all
# !git commit -m "initial commit"
# !git remote set-url origin https://{token}@github.com/{username}/{repo}
# !git push origin HEAD:main
